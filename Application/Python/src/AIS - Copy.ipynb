# %% [markdown]
# Imported AIS data and displayed the first rows to verify data loading and column structure

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("aisdk-2025-12-31.csv")

# %%
print(df.head())
# Out:
#            # Timestamp Type of mobile       MMSI   Latitude  Longitude  \
# 0  31/12/2025 00:00:00   Base Station    2190064  56.716575  11.519088
# 1  31/12/2025 00:00:00   Base Station    2194006  55.538870   5.033200
# 2  31/12/2025 00:00:00        Class B  219003513  56.194860  10.668912
# 3  31/12/2025 00:00:00        Class B  219010487  57.120910   8.600703
# 4  31/12/2025 00:00:00        Class A  220359000  57.494685  10.503837
#
#   Navigational status  ROT  SOG    COG  Heading  ... Length  \
# 0       Unknown value  NaN  NaN    NaN      NaN  ...    NaN
# 1       Unknown value  NaN  NaN    NaN      NaN  ...    NaN
# 2       Unknown value  NaN  0.0    NaN      NaN  ...    NaN
# 3       Unknown value  NaN  0.0  197.4    197.0  ...    NaN
# 4  Engaged in fishing  0.0  0.0  234.4    253.0  ...    NaN
#
#   Type of position fixing device Draught Destination  ETA  Data source type  \
# 0                            GPS     NaN     Unknown  NaN               AIS
# 1                       Surveyed     NaN     Unknown  NaN               AIS
# 2                      Undefined     NaN     Unknown  NaN               AIS
# 3                      Undefined     NaN     Unknown  NaN               AIS
# 4                      Undefined     NaN     Unknown  NaN               AIS
#
#     A   B   C   D
# 0 NaN NaN NaN NaN
# 1 NaN NaN NaN NaN
# 2 NaN NaN NaN NaN
# 3 NaN NaN NaN NaN
# 4 NaN NaN NaN NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# Checked dataset columns and data types to understand available vessel information.

# %%
print(df.columns)
# Out:
# Index(['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude',
#        'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO',
#        'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length',
#        'Type of position fixing device', 'Draught', 'Destination', 'ETA',
#        'Data source type', 'A', 'B', 'C', 'D'],
#       dtype='str')

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14430503 entries, 0 to 14430502
# Data columns (total 26 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   # Timestamp                     str
#  1   Type of mobile                  str
#  2   MMSI                            int64
#  3   Latitude                        float64
#  4   Longitude                       float64
#  5   Navigational status             str
#  6   ROT                             float64
#  7   SOG                             float64
#  8   COG                             float64
#  9   Heading                         float64
#  10  IMO                             str
#  11  Callsign                        str
#  12  Name                            str
#  13  Ship type                       str
#  14  Cargo type                      str
#  15  Width                           float64
#  16  Length                          float64
#  17  Type of position fixing device  str
#  18  Draught                         float64
#  19  Destination                     str
#  20  ETA                             str
#  21  Data source type                str
#  22  A                               float64
#  23  B                               float64
#  24  C                               float64
#  25  D                               float64
# dtypes: float64(13), int64(1), str(12)
# memory usage: 2.8 GB
# None

# %%
print(df.describe())
# Out:
#                MMSI      Latitude     Longitude           ROT           SOG  \
# count  1.443050e+07  1.443050e+07  1.443050e+07  1.014246e+07  1.314334e+07
# mean   2.441351e+08  5.633311e+01  1.076614e+01 -6.746096e-04  4.744826e+00
# std    1.313067e+08  1.964515e+00  1.963267e+00  3.952319e+00  8.406420e+00
# min    3.638000e+03 -8.529608e+01 -8.539242e+01 -7.087000e+02  0.000000e+00
# 25%    2.190031e+08  5.537224e+01  9.956960e+00  0.000000e+00  0.000000e+00
# 50%    2.190316e+08  5.615199e+01  1.086861e+01  0.000000e+00  0.000000e+00
# 75%    2.580590e+08  5.733197e+01  1.184341e+01  0.000000e+00  1.010000e+01
# max    9.926511e+08  9.100000e+01  9.647108e+01  7.087000e+02  1.540000e+02
#
#                 COG       Heading         Width        Length       Draught  \
# count  1.202659e+07  1.102332e+07  1.284954e+07  1.285109e+07  9.989948e+06
# mean   1.847013e+02  1.814532e+02  1.428131e+01  7.439102e+01  4.826569e+00
# std    1.098181e+02  1.039787e+02  1.205406e+01  7.490175e+01  2.931092e+00
# min    0.000000e+00  0.000000e+00  1.000000e+00  2.000000e+00  1.000000e-01
# 25%    8.240000e+01  8.400000e+01  6.000000e+00  1.700000e+01  2.500000e+00
# 50%    1.954000e+02  1.830000e+02  1.000000e+01  3.600000e+01  4.100000e+00
# 75%    2.790000e+02  2.660000e+02  1.900000e+01  1.130000e+02  6.700000e+00
# max    3.599000e+02  4.950000e+02  1.060000e+02  5.570000e+02  2.550000e+01
#
#                   A             B             C             D
# count  1.283077e+07  1.268057e+07  1.274353e+07  1.270740e+07
# mean   4.927477e+01  2.553291e+01  7.231906e+00  7.188594e+00
# std    5.874567e+01  3.812381e+01  6.735896e+00  6.662220e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+01  7.000000e+00  3.000000e+00  3.000000e+00
# 50%    1.800000e+01  1.300000e+01  5.000000e+00  5.000000e+00
# 75%    7.800000e+01  2.700000e+01  1.000000e+01  9.000000e+00
# max    5.090000e+02  3.300000e+02  6.100000e+01  6.300000e+01

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100
missing_percent = missing_percent.sort_values(ascending=False)

missing_percent.map(lambda x: f"{x:.2f}%")
# Out:
# Cargo type                        85.73%
# ETA                               41.97%
# Draught                           30.77%
# ROT                               29.72%
# Heading                           23.61%
# COG                               16.66%
# B                                 12.13%
# D                                 11.94%
# C                                 11.69%
# A                                 11.09%
# Width                             10.96%
# Length                            10.94%
# SOG                                8.92%
# Name                               8.44%
# Destination                        0.02%
# Type of mobile                     0.00%
# # Timestamp                        0.00%
# Navigational status                0.00%
# MMSI                               0.00%
# Latitude                           0.00%
# Longitude                          0.00%
# Ship type                          0.00%
# Type of position fixing device     0.00%
# IMO                                0.00%
# Callsign                           0.00%
# Data source type                   0.00%
# dtype: str

# %%
df['MMSI'].nunique()
# Out:
# 2766

# %%
sample_ship = df[df['MMSI'] == df['MMSI'].iloc[0]]

plt.plot(sample_ship['Longitude'], sample_ship['Latitude'])
plt.title("Sample Vessel Trajectory")
plt.show()

# %%
df = df.drop(columns=[
    'ROT',
    'Heading',
    'Name',
    'Callsign',
    'Cargo type',
    'Width',
    'Length',
    'Draught',
    'Destination',
    'ETA',
    'A','B','C','D'
])

# %%
df.shape
# Out:
# (14430503, 12)

# %%
df['# Timestamp'] = pd.to_datetime(df['# Timestamp'], dayfirst=True)

# %%
df = df.sort_values(['MMSI', '# Timestamp'])

# %%
df = df[(df['SOG'] >= 0) & (df['SOG'] <= 25)]

# %%
df['lat_diff'] = df.groupby('MMSI')['Latitude'].diff()
df['lon_diff'] = df.groupby('MMSI')['Longitude'].diff()
df = df[(df['lat_diff'].abs() < 1) & (df['lon_diff'].abs() < 1)]

# %%
df = df[df['Ship type'] == 'Tanker']

# %%
vessel_mmsi = df['MMSI'].value_counts().index[0]
vessel = df[df['MMSI'] == vessel_mmsi]

# %%
vessel = vessel[
    (vessel['Latitude'] > 54.5) &
    (vessel['Latitude'] < 58.0) &
    (vessel['Longitude'] > 7.5) &
    (vessel['Longitude'] < 15.5)
]

# %%
start_time = vessel['# Timestamp'].min()
end_time = vessel['# Timestamp'].max()

duration = end_time - start_time

print(start_time, end_time, duration)
# Out:
# 2025-12-31 00:01:39 2025-12-31 23:59:39 0 days 23:58:00

# %%
import numpy as np

def haversine_np(lat1, lon1, lat2, lon2):
    R = 6371.0  # km

    lat1 = np.radians(lat1)
    lon1 = np.radians(lon1)
    lat2 = np.radians(lat2)
    lon2 = np.radians(lon2)

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = np.sin(dlat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    c = 2*np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return R * c

# %%
vessel = vessel.sort_values('# Timestamp').copy()

vessel['dist_km'] = haversine_np(
    vessel['Latitude'].shift(),
    vessel['Longitude'].shift(),
    vessel['Latitude'],
    vessel['Longitude']
)

distance_km = vessel['dist_km'].sum(skipna=True)
print("Distance (km):", distance_km)
# Out:
# Distance (km): 644.9023300890053

# %%
vessel_moving = vessel[vessel['SOG'] > 2]

# %%
print("Start time:", start_time)
print("End time:", end_time)
print("Duration:", duration)
print("Distance (km):", distance_km)
# Out:
# Start time: 2025-12-31 00:01:39
# End time: 2025-12-31 23:59:39
# Duration: 0 days 23:58:00
# Distance (km): 644.9023300890053

# %%
vessel['gap'] = vessel['# Timestamp'].diff()
print(vessel['gap'].max())
# Out:
# 0 days 02:09:02

# %%
print("Start:", start_time)
print("End:", end_time)
print("Duration:", duration)
print("Distance (km):", distance_km)
print("Max AIS gap:", vessel['gap'].max())
# Out:
# Start: 2025-12-31 00:01:39
# End: 2025-12-31 23:59:39
# Duration: 0 days 23:58:00
# Distance (km): 644.9023300890053
# Max AIS gap: 0 days 02:09:02

# %%
plt.figure(figsize=(6,6))
plt.plot(vessel_moving['Longitude'], vessel_moving['Latitude'])

plt.scatter(vessel_moving.iloc[0]['Longitude'],
            vessel_moving.iloc[0]['Latitude'], color='green', label='Start')

plt.scatter(vessel_moving.iloc[-1]['Longitude'],
            vessel_moving.iloc[-1]['Latitude'], color='red', label='End')

plt.legend()
plt.title("Clean Tanker Voyage")
plt.show()

# %%
print("Max AIS gap:", vessel['gap'].max())
# Out:
# Max AIS gap: 0 days 02:09:02

# %%
print("Start time:", start_time)
print("End time:", end_time)
print("Duration:", duration)
print("Distance (km):", distance_km)
# Out:
# Start time: 2025-12-31 00:01:39
# End time: 2025-12-31 23:59:39
# Duration: 0 days 23:58:00
# Distance (km): 644.9023300890053

# %%
vessel['gap'] = vessel['# Timestamp'].diff()
vessel['gap'].max()
# Out:
# Timedelta('0 days 02:09:02')

# %%
df['MMSI'].nunique()
# Out:
# 198

# %%
df['IMO'].nunique()
# Out:
# 194

# %%
df['IMO'].value_counts().head(10)
# Out:
# IMO
# 9748899    40291
# 9466142    39071
# 9410648    30169
# 9254977    26665
# 9709489    24903
# 9360415    24836
# 9723289    23141
# 9438860    22570
# 9960590    21997
# 9409273    21971
# Name: count, dtype: int64

# %%
df.groupby('IMO')['MMSI'].nunique().sort_values(ascending=False)
# Out:
# IMO
# Unknown    5
# 1017050    1
# 8416786    1
# 8661020    1
# 8913708    1
#           ..
# 9983968    1
# 9987615    1
# 9988279    1
# 9988994    1
# 9993810    1
# Name: MMSI, Length: 194, dtype: int64

# %%
print(ship.shape)
# Out:
# (14198, 14)

# %%
df['IMO'].unique()[:10]
# Out:
# <StringArray>
# ['9684110', '9819882', '9819052', '9458028', '9152820', '9710311', '9988279',
#  '9164093', '9298193', '9308065']
# Length: 10, dtype: str

# %%
ship = df[df['IMO'] == '9458028']

# %%
print(ship.shape)
# Out:
# (14198, 14)

# %%
plt.figure(figsize=(7,7))

# Trajectory (all points)
plt.plot(ship['Longitude'], ship['Latitude'], linewidth=1)

# Start point (A)
plt.scatter(ship.iloc[0]['Longitude'], ship.iloc[0]['Latitude'], s=80, c='green', label='Start (A)')

# End point (B)
plt.scatter(ship.iloc[-1]['Longitude'], ship.iloc[-1]['Latitude'], s=80, c='red', label='End (B)')

plt.title("Vessel Trajectory with Start-End")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend()
plt.show()

# %%
import folium

map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=6)

for _, row in df.sample(5000).iterrows(): 
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=1
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_547c76c8f47fc19d793877434efd9dfd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_547c76c8f47fc19d793877434efd9dfd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_547c76c8f47fc19d793877434efd9dfd = L.map(
#                 &quot;map_547c76c8f47fc19d793877434efd9dfd&quot;,
#                 {
#                     center: [56.463353477033024, 10.983302916426675],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ccdfa36212d6a4e3bddab78673d9908 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ccdfa36212d6a4e3bddab78673d9908.addTo(map_547c76c8f47fc19d793877434efd9dfd);
#
#
#             var circle_marker_991a98c4de3b8b537c638702e9378c92 = L.circleMarker(
#                 [55.267415, 12.785155],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_547c76c8f47fc19d793877434efd9dfd);
#
#
#             var circle_marker_5e6f37efe1712d5aafc21fc2443777f8 = L.circleMarker(
#                 [57.290272, 8.212325],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_547c76c8f47fc19d793877434efd9dfd);
#
#
#             var circle_marker_6da781bce0383c24b9680ce2745d6f5b = L.circleMarker(
#                 [54.43154, 12.10007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_547c76c8f47fc19d793877434efd9dfd);
#
#
#             var circle_marker_a3a005a5f8293d5d9dced5f3ced9252f = L.circleMarker(
#                 [57.804013, 10.339083],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_547c76c8f47fc19d793877434efd9dfd);
#
#
#             var circle_marker_39b0b399314fbdadb3458a9698594916 = L.circleMarker(
#                 [57.221373, 8.613625],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_547c76c8f47fc19d793877434efd9dfd);
#
#
#             var circle_marker_c7ef2bc4699cb1eb2aad8c94be7f50fb = L.circleMarker(
#                 [57.597008, 9.153848],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quo
